# %% [markdown]
# <a href="https://colab.research.google.com/github/bloosterone/AluraStore/blob/main/Copia_de_AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
precios_tienda1 = tienda['Precio']
promedio_ventast1= round(float(precios_tienda1.mean()), 2)
promedio_ventast1
# Out:
# 487867.91

# %%
precios_tienda2 = tienda2['Precio']
promedio_ventast2= round(float(precios_tienda2.mean()), 2)
promedio_ventast2
# Out:
# 473227.43

# %%
precios_tienda3 = tienda3['Precio']
promedio_ventast3= round(float(precios_tienda3.mean()), 2)
promedio_ventast3
# Out:
# 465459.77

# %%
precios_tienda4 = tienda4['Precio']
promedio_ventast4= round(float(precios_tienda4.mean()), 2)
promedio_ventast4
# Out:
# 440362.89

# %% [markdown]
# # 2. Ventas por categoría

# %%
categoriast1 = tienda['Categoría del Producto']
conteot1 = {}
for categoria in categoriast1:
  if categoria in conteot1:
    conteot1[categoria] += 1
  else:
    conteot1[categoria] = 1


categoria_ordenadat1 = dict(sorted(conteot1.items(), key=lambda item: item[1], reverse=True))
categoria_ordenadalistat1 = list(categoria_ordenadat1.items())
categoria_ordenadalistat1
# Out:
# [('Muebles', 465),
#  ('Electrónicos', 448),
#  ('Juguetes', 324),
#  ('Electrodomésticos', 312),
#  ('Deportes y diversión', 284),
#  ('Instrumentos musicales', 182),
#  ('Libros', 173),
#  ('Artículos para el hogar', 171)]

# %%
categoriast2 = tienda2['Categoría del Producto']
conteot2 = {}
for categoria in categoriast2:
  if categoria in conteot2:
    conteot2[categoria] += 1
  else:
    conteot2[categoria] = 1

categoria_ordenadat2 = dict(sorted(conteot2.items(), key=lambda item: item[1], reverse=True))
categoria_ordenadalistat2 = list(categoria_ordenadat2.items())
categoria_ordenadalistat2
# Out:
# [('Muebles', 442),
#  ('Electrónicos', 422),
#  ('Juguetes', 313),
#  ('Electrodomésticos', 305),
#  ('Deportes y diversión', 275),
#  ('Instrumentos musicales', 224),
#  ('Libros', 197),
#  ('Artículos para el hogar', 181)]

# %%
categoriast3 = tienda3['Categoría del Producto']
conteot3 = {}
for categoria in categoriast3:
  if categoria in conteot3:
    conteot3[categoria] += 1
  else:
    conteot3[categoria] = 1

categoria_ordenadat3 = dict(sorted(conteot3.items(), key=lambda item: item[1], reverse=True))
categoria_ordenadalistat3 = list(categoria_ordenadat3.items())
categoria_ordenadalistat3
# Out:
# [('Muebles', 499),
#  ('Electrónicos', 451),
#  ('Juguetes', 315),
#  ('Electrodomésticos', 278),
#  ('Deportes y diversión', 277),
#  ('Libros', 185),
#  ('Instrumentos musicales', 177),
#  ('Artículos para el hogar', 177)]

# %%
categoriast4 = tienda4['Categoría del Producto']
conteot4 = {}
for categoria in categoriast4:
  if categoria in conteot4:
    conteot4[categoria] += 1
  else:
    conteot4[categoria] = 1

categoria_ordenadat4 = dict(sorted(conteot4.items(), key=lambda item: item[1], reverse=True))
categoria_ordenadalistat4 = list(categoria_ordenadat4.items())
categoria_ordenadalistat4
# Out:
# [('Muebles', 480),
#  ('Electrónicos', 451),
#  ('Juguetes', 338),
#  ('Deportes y diversión', 277),
#  ('Electrodomésticos', 254),
#  ('Artículos para el hogar', 201),
#  ('Libros', 187),
#  ('Instrumentos musicales', 170)]

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificaciont1 = tienda['Calificación']
promedio_calificaciont1= round(float(calificaciont1.mean()), 2)
promedio_calificaciont1
# Out:
# 3.98

# %%
calificaciont2 = tienda2['Calificación']
promedio_calificaciont2= round(float(calificaciont2.mean()), 2)
promedio_calificaciont2
# Out:
# 4.04

# %%
calificaciont3 = tienda3['Calificación']
promedio_calificaciont3= round(float(calificaciont3.mean()), 2)
promedio_calificaciont3
# Out:
# 4.05

# %%
calificaciont4 = tienda4['Calificación']
promedio_calificaciont4= round(float(calificaciont4.mean()), 2)
promedio_calificaciont4
# Out:
# 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productost1 = tienda['Producto']
conteo = {}
for producto in productost1:
  if producto in conteo:
    conteo[producto] += 1
  else:
    conteo[producto] = 1

conteo_ordenadot1 = dict(sorted(conteo.items(), key=lambda item: item[1], reverse=True))
for producto, cantidad in conteo_ordenadot1.items():
    print(f'{producto}: {cantidad} ventas')
# Out:
# Microondas: 60 ventas
# TV LED UHD 4K: 60 ventas
# Armario: 60 ventas
# Secadora de ropa: 58 ventas
# Bloques de construcción: 56 ventas
# Mesa de noche: 56 ventas
# Balón de baloncesto: 55 ventas
# Refrigerador: 54 ventas
# Bicicleta: 54 ventas
# Vaso térmico: 54 ventas
# Impresora: 54 ventas
# Batería: 53 ventas
# Carrito de control remoto: 52 ventas
# Cubertería: 52 ventas
# Modelado predictivo: 51 ventas
# Auriculares: 50 ventas
# Ajedrez de madera: 49 ventas
# Iphone 15: 49 ventas
# Lavavajillas: 48 ventas
# Lavadora de ropa: 47 ventas
# Guitarra eléctrica: 47 ventas
# Silla de oficina: 46 ventas
# Sofá reclinable: 46 ventas
# Guitarra acústica: 46 ventas
# Estufa: 45 ventas
# Kit de bancas: 44 ventas
# Cama box: 44 ventas
# Cubo mágico 8x8: 44 ventas
# Mesa de centro: 44 ventas
# Cama king: 44 ventas
# Smart TV: 44 ventas
# Juego de mesa: 43 ventas
# Set de ollas: 43 ventas
# Smartwatch: 43 ventas
# Balón de voleibol: 42 ventas
# Dashboards con Power BI: 42 ventas
# ...

# %%
productost2 = tienda2['Producto']
conteo = {}
for producto in productost2:
  if producto in conteo:
    conteo[producto] += 1
  else:
    conteo[producto] = 1

conteo_ordenado = dict(sorted(conteo.items(), key=lambda item: item[1], reverse=True))
for producto, cantidad in conteo_ordenado.items():
    print(f'{producto}: {cantidad} ventas')
# Out:
# Iniciando en programación: 65 ventas
# Microondas: 62 ventas
# Batería: 61 ventas
# Pandereta: 58 ventas
# Guitarra acústica: 58 ventas
# Secadora de ropa: 57 ventas
# Iphone 15: 55 ventas
# Bloques de construcción: 54 ventas
# Armario: 54 ventas
# Set de ollas: 52 ventas
# Cuerda para saltar: 50 ventas
# Silla de oficina: 49 ventas
# Refrigerador: 49 ventas
# Lavadora de ropa: 49 ventas
# Muñeca bebé: 48 ventas
# Vaso térmico: 47 ventas
# Guitarra eléctrica: 47 ventas
# Cama box: 47 ventas
# Carrito de control remoto: 47 ventas
# Modelado predictivo: 46 ventas
# Set de vasos: 46 ventas
# Lavavajillas: 46 ventas
# Balón de voleibol: 46 ventas
# Cama king: 45 ventas
# Mochila: 45 ventas
# Cubo mágico 8x8: 45 ventas
# Ajedrez de madera: 45 ventas
# Bicicleta: 45 ventas
# TV LED UHD 4K: 45 ventas
# Mesa de centro: 45 ventas
# Kit de bancas: 45 ventas
# Tablet ABXY: 44 ventas
# Olla de presión: 44 ventas
# Auriculares con micrófono: 44 ventas
# Sofá reclinable: 44 ventas
# ...

# %%
productost3 = tienda3['Producto']
conteo = {}
for producto in productost3:
  if producto in conteo:
    conteo[producto] += 1
  else:
    conteo[producto] = 1

conteo_ordenado = dict(sorted(conteo.items(), key=lambda item: item[1], reverse=True))
for producto, cantidad in conteo_ordenado.items():
    print(f'{producto}: {cantidad} ventas')
# Out:
# Kit de bancas: 57 ventas
# Mesa de comedor: 56 ventas
# Cama king: 56 ventas
# Mesa de noche: 55 ventas
# Set de ollas: 55 ventas
# Smart TV: 54 ventas
# Modelado predictivo: 53 ventas
# Cuerda para saltar: 53 ventas
# Estufa: 53 ventas
# Carrito de control remoto: 52 ventas
# Bicicleta: 52 ventas
# Lavavajillas: 52 ventas
# Juego de mesa: 52 ventas
# Pandereta: 51 ventas
# Impresora: 50 ventas
# Balón de baloncesto: 50 ventas
# Refrigerador: 50 ventas
# Armario: 49 ventas
# Balón de voleibol: 48 ventas
# Tablet ABXY: 48 ventas
# Guitarra acústica: 47 ventas
# Olla de presión: 47 ventas
# Ajedrez de madera: 47 ventas
# Sillón: 47 ventas
# Silla de oficina: 46 ventas
# Dinosaurio Rex: 46 ventas
# Iniciando en programación: 46 ventas
# Cama box: 46 ventas
# Iphone 15: 46 ventas
# Smartwatch: 46 ventas
# Ciencia de datos con Python: 46 ventas
# Secadora de ropa: 45 ventas
# Sofá reclinable: 45 ventas
# Celular ABXY: 44 ventas
# Cubo mágico 8x8: 44 ventas
# Auriculares: 43 ventas
# ...

# %%
productost4 = tienda4['Producto']
conteo = {}
for producto in productost4:
  if producto in conteo:
    conteo[producto] += 1
  else:
    conteo[producto] = 1

conteo_ordenado = dict(sorted(conteo.items(), key=lambda item: item[1], reverse=True))
for producto, cantidad in conteo_ordenado.items():
    print(f'{producto}: {cantidad} ventas')
# Out:
# Cama box: 62 ventas
# Cubertería: 59 ventas
# Dashboards con Power BI: 56 ventas
# Cama king: 56 ventas
# Mesa de noche: 55 ventas
# Mesa de comedor: 55 ventas
# Carrito de control remoto: 55 ventas
# Smart TV: 54 ventas
# Bloques de construcción: 54 ventas
# Pandereta: 52 ventas
# Balón de baloncesto: 50 ventas
# Modelado predictivo: 50 ventas
# Impresora: 50 ventas
# Asistente virtual: 50 ventas
# Set de ollas: 50 ventas
# Iphone 15: 48 ventas
# Muñeca bebé: 48 ventas
# Balón de voleibol: 48 ventas
# Vaso térmico: 48 ventas
# Batería: 48 ventas
# Juego de mesa: 48 ventas
# Microondas: 48 ventas
# Estufa: 47 ventas
# Dinosaurio Rex: 47 ventas
# Cubo mágico 8x8: 47 ventas
# Sofá reclinable: 47 ventas
# Set de vasos: 46 ventas
# Olla de presión: 46 ventas
# Tablet ABXY: 45 ventas
# Bicicleta: 45 ventas
# Sillón: 45 ventas
# Auriculares: 44 ventas
# Mesa de centro: 44 ventas
# Lavavajillas: 43 ventas
# Cuerda para saltar: 43 ventas
# Iniciando en programación: 43 ventas
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
enviost1 = tienda['Costo de envío']
promedio_enviost1 = round(float(enviost1.mean()),2)
promedio_enviost1
# Out:
# 26018.61

# %%
enviost2 = tienda2['Costo de envío']
promedio_enviost2 = round(float(enviost2.mean()),2)
promedio_enviost2
# Out:
# 25216.24

# %%
enviost3 = tienda['Costo de envío']
promedio_enviost3 = round(float(enviost3.mean()),2)
promedio_enviost3
# Out:
# 26018.61

# %%
enviost4 = tienda4['Costo de envío']
promedio_enviost4 = round(float(enviost4.mean()),2)
promedio_enviost4
# Out:
# 23459.46

# %% [markdown]
# # Graficos

# %%
import matplotlib.pyplot as plt

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas = [promedio_ventast1, promedio_ventast2, promedio_ventast3, promedio_ventast4]

plt.bar(tiendas, ventas)
plt.yticks(range(0, 500001, 50000))

plt.title('Analisis de Facturación')
plt.xlabel('Tiendas')
plt.ylabel('Cantidad vendida')

plt.show()

# %%
# Datos de ejemplo
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
promedios = [promedio_calificaciont1, promedio_calificaciont2, promedio_calificaciont3, promedio_calificaciont4]

# Crear gráfico de líneas
plt.plot(tiendas, promedios)

# Título y etiquetas
plt.title('Calificaciones Promedio')
plt.xlabel('Tiendas')
plt.ylabel('Valores')

# Mostrar gráfico
plt.show()

# %%
categorias = []
porcentajes = []
for producto, cantidad in categoria_ordenadat2.items():
    categorias.append(producto)
    porcentajes.append(cantidad)

plt.pie(porcentajes, labels=categorias, autopct='%1.1f%%')

plt.title('Distribución de ventas por categoría (TIENDA 1)')

plt.show()

# %%
categorias = []
porcentajes = []
for producto, cantidad in categoria_ordenadat1.items():
    categorias.append(producto)
    porcentajes.append(cantidad)

plt.pie(porcentajes, labels=categorias, autopct='%1.1f%%')

plt.title('Distribución de ventas por categoría (TIENDA 2)')

plt.show()

# %%
categorias = []
porcentajes = []
for producto, cantidad in categoria_ordenadat3.items():
    categorias.append(producto)
    porcentajes.append(cantidad)

plt.pie(porcentajes, labels=categorias, autopct='%1.1f%%')

plt.title('Distribución de ventas por categoría (TIENDA 3)')

plt.show()

# %%
categorias = []
porcentajes = []
for producto, cantidad in categoria_ordenadat4.items():
    categorias.append(producto)
    porcentajes.append(cantidad)

plt.pie(porcentajes, labels=categorias, autopct='%1.1f%%')

plt.title('Distribución de ventas por categoría (TIENDA 4)')

plt.show()
